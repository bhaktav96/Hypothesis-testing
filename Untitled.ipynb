# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from datetime import datetime

url_1 = "https://dshs.texas.gov/coronavirus/TexasCOVID19DailyCountyCaseCountData.xlsx"
url_2 = "https://dshs.texas.gov/coronavirus/TexasCOVID19DailyCountyFatalityCountData.xlsx"
url_3 = "https://dshs.texas.gov/coronavirus/TexasCOVID-19CumulativeTestsOverTimebyCounty.xlsx"
url_4 = "https://www2.census.gov/programs-surveys/popest/tables/2010-2019/counties/totals/co-est2019-annres-48.xlsx"

county_cases = pd.read_excel(url_1,skiprows=2)
fatality_cases = pd.read_excel(url_2,skiprows = 2)
test_cases = pd.read_excel(url_3,skiprows = 1)
population = pd.read_excel(url_4,skiprows =3)

# %%
population
# Out:
#                                             Unnamed: 0      Census  \
# 0                                                Texas  25145561.0
# 1                              .Anderson County, Texas     58458.0
# 2                               .Andrews County, Texas     14786.0
# 3                              .Angelina County, Texas     86771.0
# 4                               .Aransas County, Texas     23158.0
# ..                                                 ...         ...
# 255  Note: The estimates are based on the 2010 Cens...         NaN
# 256                                Suggested Citation:         NaN
# 257  Annual Estimates of the Resident Population fo...         NaN
# 258    Source: U.S. Census Bureau, Population Division         NaN
# 259                           Release Date: March 2020         NaN
#
#      Estimates Base        2010        2011        2012        2013  \
# 0        25146091.0  25241971.0  25645629.0  26084481.0  26480266.0
# 1           58452.0     58493.0     58394.0     58059.0     57960.0
# 2           14786.0     14849.0     15386.0     16105.0     16779.0
# 3           86771.0     86905.0     87297.0     87509.0     87312.0
# 4           23158.0     23181.0     23216.0     23459.0     23889.0
# ..              ...         ...         ...         ...         ...
# 255             NaN         NaN         NaN         NaN         NaN
# 256             NaN         NaN         NaN         NaN         NaN
# 257             NaN         NaN         NaN         NaN         NaN
# 258             NaN         NaN         NaN         NaN         NaN
# 259             NaN         NaN         NaN         NaN         NaN
#
#            2014        2015        2016        2017        2018        2019
# 0    26964333.0  27470056.0  27914410.0  28295273.0  28628666.0  28995881.0
# 1       57829.0     57639.0     57526.0     58175.0     57974.0     57735.0
# 2       17435.0     18072.0     17791.0     17603.0     18011.0     18705.0
# 3       87567.0     87829.0     87682.0     87572.0     86810.0     86715.0
# 4       24566.0     24800.0     25162.0     25392.0     23446.0     23510.0
# ..          ...         ...         ...         ...         ...         ...
# 255         NaN         NaN         NaN         NaN         NaN         NaN
# 256         NaN         NaN         NaN         NaN         NaN         NaN
# 257         NaN         NaN         NaN         NaN         NaN         NaN
# 258         NaN         NaN         NaN         NaN         NaN         NaN
# 259         NaN         NaN         NaN         NaN         NaN         NaN
#
# [260 rows x 13 columns]

# %%
url_hospital = "/home/ak/Downloads/counties_NO_INTERVENTION_timeseries.csv"
df = pd.read_csv(url_hospital)

# %%
print(df)
# Out:
#               date  hospitalBedsRequired  hospitalBedCapacity  ICUBedsInUse  \
# 0       2020-04-23                     0                   66           NaN
# 1       2020-04-24                     0                   66           NaN
# 2       2020-04-25                     0                   66           NaN
# 3       2020-04-26                     0                   66           NaN
# 4       2020-04-27                     0                   66           NaN
# ...            ...                   ...                  ...           ...
# 717655  2020-12-18                     6                   88           NaN
# 717656  2020-12-19                     6                   88           NaN
# 717657  2020-12-20                     5                   88           NaN
# 717658  2020-12-21                     5                   88           NaN
# 717659  2020-12-22                     4                   88           NaN
#
#         ICUBedCapacity  ventilatorsInUse  ventilatorCapacity  RtIndicator  \
# 0                    2                 0                   5     1.158543
# 1                    2                 0                   5     1.155993
# 2                    2                 0                   5     1.156872
# 3                    2                 0                   5     1.160555
# 4                    2                 0                   5     1.166845
# ...                ...               ...                 ...          ...
# 717655               4                 1                  10          NaN
# 717656               4                 1                  10          NaN
# 717657               4                 1                  10          NaN
# 717658               4                 0                  10          NaN
# 717659               4                 0                  10          NaN
#
#         RtIndicatorCI90  cumulativeDeaths  ...  currentSusceptible  \
# 0              0.877993                 0  ...               55830
# 1              0.872955                 0  ...               55816
# 2              0.872702                 0  ...               55799
# 3              0.865865                 0  ...               55778
# 4              0.869823                 0  ...               55751
# ...                 ...               ...  ...                 ...
# 717655              NaN               128  ...                6339
# 717656              NaN               128  ...                6332
# 717657              NaN               128  ...                6326
# 717658              NaN               129  ...                6320
# 717659              NaN               129  ...                6314
#
#         currentExposed  countryName    stateName       countyName  \
# 0                   21           US      Alabama   Autauga County
# 1                   25           US      Alabama   Autauga County
# 2                   30           US      Alabama   Autauga County
# 3                   38           US      Alabama   Autauga County
# 4                   47           US      Alabama   Autauga County
# ...                ...          ...          ...              ...
# 717655              22           US  Puerto Rico  Yauco Municipio
# 717656              20           US  Puerto Rico  Yauco Municipio
# 717657              19           US  Puerto Rico  Yauco Municipio
# 717658              17           US  Puerto Rico  Yauco Municipio
# 717659              16           US  Puerto Rico  Yauco Municipio
#
#                intervention   fips lat  long  lastUpdatedDate
# 0       STRONG_INTERVENTION   1001 NaN   NaN       2020-09-23
# 1       STRONG_INTERVENTION   1001 NaN   NaN       2020-09-23
# 2       STRONG_INTERVENTION   1001 NaN   NaN       2020-09-23
# 3       STRONG_INTERVENTION   1001 NaN   NaN       2020-09-23
# 4       STRONG_INTERVENTION   1001 NaN   NaN       2020-09-23
# ...                     ...    ...  ..   ...              ...
# 717655    WEAK_INTERVENTION  72153 NaN   NaN       2020-09-23
# 717656    WEAK_INTERVENTION  72153 NaN   NaN       2020-09-23
# 717657    WEAK_INTERVENTION  72153 NaN   NaN       2020-09-23
# 717658    WEAK_INTERVENTION  72153 NaN   NaN       2020-09-23
# 717659    WEAK_INTERVENTION  72153 NaN   NaN       2020-09-23
#
# [717660 rows x 22 columns]
